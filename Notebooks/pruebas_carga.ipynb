# %%
import pandas as pd
import json

# %%
with open('../data/data_salto/concursos/concursos_salto_nacional_2025.json', 'r', encoding='utf-8') as file:
    datos_concursos = json.load(file)

df_concursos = pd.DataFrame(datos_concursos)
df_concursos = df_concursos.rename(columns = {"Nombre": "Concurso"})
df_concursos["Concurso"] = df_concursos["Concurso"].str.strip()
df_concursos
# Out:
#                                               Concurso Categoría Provincia  \
# 0                                       CSN3* Invierno    CSN***   Sevilla
# 1                                SPRING MET I 2025 YH*   CSI YH*  Valencia
# 2                        SPRING MET I 2025 - SILVER 1*      CSI*  Valencia
# 3                          SPRING MET I 2025 - GOLD 2*     CSI**  Valencia
# 4    CSIYH* - 1st Week Andalucía Pre-Sunshine Tour ...   CSI YH*     Cádiz
# ..                                                 ...       ...       ...
# 119                                SPRING MET IV - YH*   CSI YH*  Valencia
# 120                       SPRING MET IV - CSI1* SILVER      CSI*  Valencia
# 121                         SPRING MET IV - CSI3* GOLD    CSI***  Valencia
# 122                       SPRING MET IV - CSI1* BRONZE      CSI*  Valencia
# 123                              CSN3* Copa Presidente    CSN***   Sevilla
#
#                       Localidad           Disciplina  \
# 0              Real Club Pineda  Salto de Obstáculos
# 1    Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 2    Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 3    Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 4            Dehesa Montenmedio  Salto de Obstáculos
# ..                          ...                  ...
# 119                        Ceon  Salto de Obstáculos
# 120                        Ceon  Salto de Obstáculos
# 121                        Ceon  Salto de Obstáculos
# 122                        Ceon  Salto de Obstáculos
# 123            Real Club Pineda  Salto de Obstáculos
#
#                                  Federación Resultados   País      Inicio  \
# 0                Federación Hípica Andaluza        Ver  Epaña  10/01/2025
# 1    Federación Hípica Comunidad Valenciana        Ver  Epaña  14/01/2025
# 2    Federación Hípica Comunidad Valenciana        Ver  Epaña  16/01/2025
# 3    Federación Hípica Comunidad Valenciana        Ver  Epaña  16/01/2025
# 4                Federación Hípica Andaluza        Ver  Epaña  16/01/2025
# ..                                      ...        ...    ...         ...
# 119  Federación Hípica Comunidad Valenciana        Ver  Epaña  22/04/2025
# 120  Federación Hípica Comunidad Valenciana        Ver  Epaña  24/04/2025
# 121  Federación Hípica Comunidad Valenciana        Ver  Epaña  24/04/2025
# 122  Federación Hípica Comunidad Valenciana        Ver  Epaña  25/04/2025
# 123              Federación Hípica Andaluza        Ver  Epaña  25/04/2025
#
#           Final         Ambito
# 0    12/01/2025       Nacional
# 1    16/01/2025  Internacional
# 2    18/01/2025  Internacional
# 3    19/01/2025  Internacional
# 4    19/01/2025  Internacional
# ..          ...            ...
# 119  24/04/2025  Internacional
# 120  26/04/2025  Internacional
# 121  27/04/2025  Internacional
# 122  27/04/2025  Internacional
# 123  27/04/2025       Nacional
#
# [124 rows x 11 columns]

# %%
df_concursos.iloc[0,0]
# Out:
# 'CSN3* Invierno'

# %%
len(df_concursos["Concurso"].unique())
# Out:
# 78

# %%
pd.set_option('display.max_columns', None)

# %%
df_pruebas_resultados = pd.read_pickle("../data/data_salto/resultados_combinados_2025.pkl")
df_pruebas_resultados.head()
# Out:
#   Estado Posicion Lic_jinete                       Jinete Pais_jinete  \
# 0    FIN        1     284725  Pedro Miguel DA SILVA MANSO         ESP
# 1    FIN        2      77612        Ignacio ASTOLFI LÓPEZ         ESP
# 2    FIN        3     306183     Francisco PICAO CALDEIRA         ESP
# 3    FIN        4       1004          Jesús TORRES GARCÍA         ESP
# 4    FIN        5     367363              Nina FAGERSTROM         ESP
#
#   Lic_caballo              Caballo Raza_caballo Pais_caballo Puntuacion  \
# 0      169882  BRIDGETOWN JONES OS      (Indt.)          ESP    0/59,91
# 1      157373       QUINTO BLUE PS        OLDBG          ESP    0/63,23
# 2      145996         FLOR DU PASO        CRPOR          ESP    0/65,58
# 3      170075          DIABETTO PS        OLDBG          ESP    0/66,00
# 4      170155    HASENACHER CERVIN         ZANG          ESP    0/66,78
#
#    Premio Dinero_premio                   Prueba Fecha_prueba        Concurso  \
# 0    True           450  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 1    True           300  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 2    True           200  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 3    True           150  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 4    True           125  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
#
#   Ptos_obs_R1 Ptos_tiempo_R1 Tiempo_R1 Ptos_obs_R2 Ptos_tiempo_R2 Tiempo_R2  \
# 0         0.0            NaN     59.91        None           None      None
# 1         0.0            NaN     63.23        None           None      None
# 2         0.0            NaN     65.58        None           None      None
# 3         0.0            NaN      66.0        None           None      None
# 4         0.0            NaN     66.78        None           None      None
#
#   Ptos_obs_R3 Ptos_tiempo_R3 Tiempo_R3
# 0        None           None      None
# 1        None           None      None
# 2        None           None      None
# 3        None           None      None
# 4        None           None      None

# %%
df_pruebas_resultados[df_pruebas_resultados["Concurso"] == "CSIYH* - 1st Week XXXI Andalucía Sunshine Tour 2025"]
# Out:
#       Estado Posicion Lic_jinete                   Jinete Pais_jinete  \
# 11608    FIN        1   10019435     Sonia HUNGERBÜHLER .         ESP
# 11609    FIN        1   10056475          Kurt GHESQUIERE         ESP
# 11610    FIN        1   10180588        Stephanie SERVAIS         BEL
# 11611    FIN        1   10043850          Alfie BRADSTOCK         GBR
# 11612    FIN        1   10041101           Laura ROBINSON         GBR
# ...      ...      ...        ...                      ...         ...
# 13128    FIN       74   10058898  Kendra Claricia BRINKOP         GER
# 13129    FIN       75   10006490               Jemma KIRK         GBR
# 13130    RET      RET   10192397              Noah KELLER         SUI
# 13131    RET      RET   10074011       Thibault VERMEULEN         BEL
# 13132    ELI      ELI   10132578            Nesrine MASON         FRA
#
#       Lic_caballo                         Caballo Raza_caballo Pais_caballo  \
# 11608     109BK20                    CHADANDRA PS        OLDBG          ESP
# 11609     109BK05                  YCH PORTOBELLO          CDE          ESP
# 11610     109BR15             KATAPULTE RIVERLAND         None          BEL
# 11611     109AW15                       PRIMERA B         None          GBR
# 11612     109AU63              KAOLIN DE BEAUVOIR         None          GBR
# ...           ...                             ...          ...          ...
# 13128     108LG96                CHINOOK POMMEX Z         None          BEL
# 13129     108CQ58           CASSIDY VH KAPELHOF Z         None          IRL
# 13130     108DJ53                       UNCLE SAM         None          SUI
# 13131     108LG83  CATRICIA CORNET VD KREKEBEKE Z         None          BEL
# 13132     108DD89            HELIYA DES CARMILLES         None          ITA
#
#                        Puntuacion  Premio Dinero_premio  \
# 11608                           0    True         10.35
# 11609                           0    True         10.35
# 11610                           0    True         10.35
# 11611                           0    True         10.35
# 11612                           0    True         10.35
# ...                           ...     ...           ...
# 13128    24(4 Obs - 20 Tpo)/99,38    True             0
# 13129  41(12 Obs - 29 Tpo)/108,82    True             0
# 13130                         RET    True             0
# 13131                         RET    True             0
# 13132                         ELI    True             0
#
#                                            Prueba Fecha_prueba  \
# 11608  5 años - 1,05 - A sin cronómetro (238.1.1)   2025-02-04
# 11609  5 años - 1,05 - A sin cronómetro (238.1.1)   2025-02-04
# 11610  5 años - 1,05 - A sin cronómetro (238.1.1)   2025-02-04
# 11611  5 años - 1,05 - A sin cronómetro (238.1.1)   2025-02-04
# 11612  5 años - 1,05 - A sin cronómetro (238.1.1)   2025-02-04
# ...                                           ...          ...
# 13128            8 años - 1,45 - A.c.c. (238.2.1)   2025-02-06
# 13129            8 años - 1,45 - A.c.c. (238.2.1)   2025-02-06
# 13130            8 años - 1,45 - A.c.c. (238.2.1)   2025-02-06
# 13131            8 años - 1,45 - A.c.c. (238.2.1)   2025-02-06
# 13132            8 años - 1,45 - A.c.c. (238.2.1)   2025-02-06
#
#                                                 Concurso Ptos_obs_R1  \
# 11608  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...        None
# 11609  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...        None
# 11610  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...        None
# 11611  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...        None
# 11612  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...        None
# ...                                                  ...         ...
# 13128  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...         4.0
# 13129  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...        12.0
# 13130  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...         NaN
# 13131  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...         NaN
# 13132  CSIYH* - 1st Week XXXI Andalucía Sunshine Tour...         NaN
#
#       Ptos_tiempo_R1 Tiempo_R1 Ptos_obs_R2 Ptos_tiempo_R2 Tiempo_R2  \
# 11608            0.0      None        None           None      None
# 11609            0.0      None        None           None      None
# 11610            0.0      None        None           None      None
# 11611            0.0      None        None           None      None
# 11612            0.0      None        None           None      None
# ...              ...       ...         ...            ...       ...
# 13128           20.0     99.38        None           None      None
# 13129           29.0    108.82        None           None      None
# 13130            NaN       NaN        None           None      None
# 13131            NaN       NaN        None           None      None
# 13132            NaN       NaN        None           None      None
#
#       Ptos_obs_R3 Ptos_tiempo_R3 Tiempo_R3
# 11608        None           None      None
# 11609        None           None      None
# 11610        None           None      None
# 11611        None           None      None
# 11612        None           None      None
# ...           ...            ...       ...
# 13128        None           None      None
# 13129        None           None      None
# 13130        None           None      None
# 13131        None           None      None
# 13132        None           None      None
#
# [1525 rows x 24 columns]

# %%
df_pruebas_resultados.iloc[0,14] == df_concursos.iloc[0,0]
# Out:
# True

# %%
df_concursos.columns
# Out:
# Index(['Concurso', 'Categoría', 'Provincia', 'Localidad', 'Disciplina',
#        'Federación', 'Resultados', 'País', 'Inicio', 'Final', 'Ambito'],
#       dtype='object')

# %%
df_pruebas_resultados.columns
# Out:
# Index(['Estado', 'Posicion', 'Lic_jinete', 'Jinete', 'Pais_jinete',
#        'Lic_caballo', 'Caballo', 'Raza_caballo', 'Pais_caballo', 'Puntuacion',
#        'Premio', 'Dinero_premio', 'Prueba', 'Fecha_prueba', 'Concurso',
#        'Ptos_obs_R1', 'Ptos_tiempo_R1', 'Tiempo_R1', 'Ptos_obs_R2',
#        'Ptos_tiempo_R2', 'Tiempo_R2', 'Ptos_obs_R3', 'Ptos_tiempo_R3',
#        'Tiempo_R3'],
#       dtype='object')

# %%
df_final = pd.merge(df_concursos, df_pruebas_resultados, on = "Concurso", how = "inner")
# condicion = (df_final['Fecha_prueba'] >= df_final['Inicio']) & (df_final['Fecha_prueba'] <= df_final['Final'])
# df_resultado = df_final[condicion]
df_final.head()
# Out:
#          Concurso Categoría Provincia         Localidad           Disciplina  \
# 0  CSN3* Invierno    CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 1  CSN3* Invierno    CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 2  CSN3* Invierno    CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 3  CSN3* Invierno    CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 4  CSN3* Invierno    CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
#
#                    Federación Resultados   País      Inicio       Final  \
# 0  Federación Hípica Andaluza        Ver  Epaña  10/01/2025  12/01/2025
# 1  Federación Hípica Andaluza        Ver  Epaña  10/01/2025  12/01/2025
# 2  Federación Hípica Andaluza        Ver  Epaña  10/01/2025  12/01/2025
# 3  Federación Hípica Andaluza        Ver  Epaña  10/01/2025  12/01/2025
# 4  Federación Hípica Andaluza        Ver  Epaña  10/01/2025  12/01/2025
#
#      Ambito Estado Posicion Lic_jinete                       Jinete  \
# 0  Nacional    FIN        1     284725  Pedro Miguel DA SILVA MANSO
# 1  Nacional    FIN        2      77612        Ignacio ASTOLFI LÓPEZ
# 2  Nacional    FIN        3     306183     Francisco PICAO CALDEIRA
# 3  Nacional    FIN        4       1004          Jesús TORRES GARCÍA
# 4  Nacional    FIN        5     367363              Nina FAGERSTROM
#
#   Pais_jinete Lic_caballo              Caballo Raza_caballo Pais_caballo  \
# 0         ESP      169882  BRIDGETOWN JONES OS      (Indt.)          ESP
# 1         ESP      157373       QUINTO BLUE PS        OLDBG          ESP
# 2         ESP      145996         FLOR DU PASO        CRPOR          ESP
# 3         ESP      170075          DIABETTO PS        OLDBG          ESP
# 4         ESP      170155    HASENACHER CERVIN         ZANG          ESP
#
#   Puntuacion  Premio Dinero_premio                   Prueba Fecha_prueba  \
# 0    0/59,91    True           450  1,30 - A c.c. (238.2.1)   2025-01-10
# 1    0/63,23    True           300  1,30 - A c.c. (238.2.1)   2025-01-10
# 2    0/65,58    True           200  1,30 - A c.c. (238.2.1)   2025-01-10
# 3    0/66,00    True           150  1,30 - A c.c. (238.2.1)   2025-01-10
# 4    0/66,78    True           125  1,30 - A c.c. (238.2.1)   2025-01-10
#
#   Ptos_obs_R1 Ptos_tiempo_R1 Tiempo_R1 Ptos_obs_R2 Ptos_tiempo_R2 Tiempo_R2  \
# 0         0.0            NaN     59.91        None           None      None
# 1         0.0            NaN     63.23        None           None      None
# 2         0.0            NaN     65.58        None           None      None
# 3         0.0            NaN      66.0        None           None      None
# 4         0.0            NaN     66.78        None           None      None
#
#   Ptos_obs_R3 Ptos_tiempo_R3 Tiempo_R3
# 0        None           None      None
# 1        None           None      None
# 2        None           None      None
# 3        None           None      None
# 4        None           None      None

# %%
len(df_final["Concurso"].unique())
# Out:
# 56

# %%
df_final = df_final[(df_final['Fecha_prueba'] >= df_final['Inicio']) & (df_final['Fecha_prueba'] <= df_final['Final'])]
df_final
# Out:
#                      Concurso Categoría Provincia                   Localidad  \
# 384     SPRING MET I 2025 YH*   CSI YH*  Valencia  Centro Ecuestre Oliva Nova
# 385     SPRING MET I 2025 YH*   CSI YH*  Valencia  Centro Ecuestre Oliva Nova
# 386     SPRING MET I 2025 YH*   CSI YH*  Valencia  Centro Ecuestre Oliva Nova
# 387     SPRING MET I 2025 YH*   CSI YH*  Valencia  Centro Ecuestre Oliva Nova
# 388     SPRING MET I 2025 YH*   CSI YH*  Valencia  Centro Ecuestre Oliva Nova
# ...                       ...       ...       ...                         ...
# 194685  CSN3* Copa Presidente    CSN***   Sevilla            Real Club Pineda
# 194686  CSN3* Copa Presidente    CSN***   Sevilla            Real Club Pineda
# 194687  CSN3* Copa Presidente    CSN***   Sevilla            Real Club Pineda
# 194688  CSN3* Copa Presidente    CSN***   Sevilla            Real Club Pineda
# 194689  CSN3* Copa Presidente    CSN***   Sevilla            Real Club Pineda
#
#                  Disciplina                              Federación  \
# 384     Salto de Obstáculos  Federación Hípica Comunidad Valenciana
# 385     Salto de Obstáculos  Federación Hípica Comunidad Valenciana
# 386     Salto de Obstáculos  Federación Hípica Comunidad Valenciana
# 387     Salto de Obstáculos  Federación Hípica Comunidad Valenciana
# 388     Salto de Obstáculos  Federación Hípica Comunidad Valenciana
# ...                     ...                                     ...
# 194685  Salto de Obstáculos              Federación Hípica Andaluza
# 194686  Salto de Obstáculos              Federación Hípica Andaluza
# 194687  Salto de Obstáculos              Federación Hípica Andaluza
# 194688  Salto de Obstáculos              Federación Hípica Andaluza
# 194689  Salto de Obstáculos              Federación Hípica Andaluza
#
#        Resultados   País      Inicio       Final         Ambito Estado  \
# 384           Ver  Epaña  14/01/2025  16/01/2025  Internacional    FIN
# 385           Ver  Epaña  14/01/2025  16/01/2025  Internacional    FIN
# 386           Ver  Epaña  14/01/2025  16/01/2025  Internacional    FIN
# 387           Ver  Epaña  14/01/2025  16/01/2025  Internacional    FIN
# 388           Ver  Epaña  14/01/2025  16/01/2025  Internacional    FIN
# ...           ...    ...         ...         ...            ...    ...
# 194685        Ver  Epaña  25/04/2025  27/04/2025       Nacional    NOP
# 194686        Ver  Epaña  25/04/2025  27/04/2025       Nacional    NOP
# 194687        Ver  Epaña  25/04/2025  27/04/2025       Nacional    NOP
# 194688        Ver  Epaña  25/04/2025  27/04/2025       Nacional    NOP
# 194689        Ver  Epaña  25/04/2025  27/04/2025       Nacional    NOP
#
#        Posicion Lic_jinete                        Jinete Pais_jinete  \
# 384           1   10006985                 Linda BRATOMI         ITA
# 385           1   10129405                 Melanie GELIN         BEL
# 386           1   10030934              Alberto GRAZIANI         ITA
# 387           1   10071984               Luigi POLESELLO         ITA
# 388           1   10006499                   Johnny PALS         NED
# ...         ...        ...                           ...         ...
# 194685      NOP     258896  Nils Roine CARLSSON BERGGREN         ESP
# 194686      NOP      18605           Carlos LANGE FRAILE         ESP
# 194687      NOP     373042                   Joel HIGHAM         ESP
# 194688      NOP     296853              Alba CONDE ORTIZ         ESP
# 194689      NOP      33415               Kurt GHESQUIERE         ESP
#
#        Lic_caballo                  Caballo Raza_caballo Pais_caballo  \
# 384        109AJ96            THE PROFESSOR         None          ITA
# 385        109AW30  OCALA VAN DE HAGENHORST         None          BEL
# 386        108FU11        BAILANDO ROYAL II         None          ITA
# 387        108NK67         JET SET DU LIROT         None          ITA
# 388        108XB10     KING PLEASURE HERO Z         None          NED
# ...            ...                      ...          ...          ...
# 194685      165031               VILANO VHL          AES          ESP
# 194686      150451               MEGA COUPE         KWPN          ESP
# 194687      171973              ESPARGARO Z         ZANG          ESP
# 194688      164581         FLASCH BO REGARD           SF          ESP
# 194689      169078      CANTIGA BEA DE MIES          CDE          ESP
#
#        Puntuacion  Premio Dinero_premio  \
# 384       0/78,80    True         29.17
# 385       0/79,70    True         29.17
# 386       0/81,11    True         29.17
# 387       0/79,45    True         29.17
# 388       0/81,18    True         29.17
# ...           ...     ...           ...
# 194685        NOP    True             0
# 194686        NOP    True             0
# 194687        NOP    True             0
# 194688        NOP    True             0
# 194689        NOP    True             0
#
#                                             Prueba Fecha_prueba Ptos_obs_R1  \
# 384     6 años - 1,25 - A sin cronómetro (238.1.1)   2025-01-14         0.0
# 385     6 años - 1,25 - A sin cronómetro (238.1.1)   2025-01-14         0.0
# 386     6 años - 1,25 - A sin cronómetro (238.1.1)   2025-01-14         0.0
# 387     6 años - 1,25 - A sin cronómetro (238.1.1)   2025-01-14         0.0
# 388     6 años - 1,25 - A sin cronómetro (238.1.1)   2025-01-14         0.0
# ...                                            ...          ...         ...
# 194685                     1,20 - A c.c. (238.2.1)   2025-04-27         NaN
# 194686                     1,20 - A c.c. (238.2.1)   2025-04-27         NaN
# 194687                     1,20 - A c.c. (238.2.1)   2025-04-27         NaN
# 194688                     1,20 - A c.c. (238.2.1)   2025-04-27         NaN
# 194689                     1,20 - A c.c. (238.2.1)   2025-04-27         NaN
#
#        Ptos_tiempo_R1 Tiempo_R1 Ptos_obs_R2 Ptos_tiempo_R2 Tiempo_R2  \
# 384               NaN      78.8        None           None      None
# 385               NaN      79.7        None           None      None
# 386               NaN     81.11        None           None      None
# 387               NaN     79.45        None           None      None
# 388               NaN     81.18        None           None      None
# ...               ...       ...         ...            ...       ...
# 194685            NaN       NaN        None           None      None
# 194686            NaN       NaN        None           None      None
# 194687            NaN       NaN        None           None      None
# 194688            NaN       NaN        None           None      None
# 194689            NaN       NaN        None           None      None
#
#        Ptos_obs_R3 Ptos_tiempo_R3 Tiempo_R3
# 384           None           None      None
# 385           None           None      None
# 386           None           None      None
# 387           None           None      None
# 388           None           None      None
# ...            ...            ...       ...
# 194685        None           None      None
# 194686        None           None      None
# 194687        None           None      None
# 194688        None           None      None
# 194689        None           None      None
#
# [48714 rows x 34 columns]

# %%
concursos_df_original = df_concursos["Concurso"].unique()
concursos_df_original
# Out:
# array(['CSN3* Invierno', 'SPRING MET I 2025 YH*',
#        'SPRING MET I 2025 - SILVER 1*', 'SPRING MET I 2025 - GOLD 2*',
#        'CSIYH* - 1st Week Andalucía Pre-Sunshine Tour 2025',
#        'CSI2* - 1st Week Andalucía Pre-Sunshine Tour 2025',
#        'SPRING MET I 2025 - BRONZE 1*',
#        'CSN2* Enero - Real Club de Polo de Barcelona',
#        'MOURA TOURS VALENCIA - SPRING TOUR', 'SPRING MET I 2025 - YH*',
#        'SPRING MET I 2025 - GOLD 3*',
#        'CSIYH* - 2nd Week Andalucía Pre-Sunshine Tour 2025',
#        'CSI3* - 2nd Week Andalucía Pre-Sunshine Tour 2025',
#        'CSN2* RIOS EQ - WINTER CUP', 'CSN 3* LA HERRADURA',
#        'CSN3* Heras Winter Propenor Showjumping', 'CSN2* LAS CADENAS',
#        'CSN2* RACE',
#        'CSIYH* - 1st Week XXXI Andalucía Sunshine Tour 2025',
#        'CSI4* - 1st Week XXXI Andalucía Sunshine Tour 2025',
#        'CSN3* Febrero - Real Club de Polo de Barcelona',
#        'CSIYH* - 2nd Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET II 2025 - YH*', 'SPRING MET II 2025 - SILVER 1*',
#        'CSI4* - 2nd Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET II 2025 - GOLD 2*', 'SPRING MET II 2025 - BRONZE 1*',
#        'CSIYH* - 3rd Week XXXI Andalucía Sunshine Tour 2025',
#        'CSI4* - 3rd Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET II 2025 - GOLD 3*', 'CSN* C.H NUEVA ATALAYA',
#        'RUTA GRANADA HIPICA', 'CSN3* F.H.M. - En Club Las Cadenas',
#        '--MOURA TOURS VALENCIA - SPRING TOUR',
#        'CSIYH* - 4th Week XXXI Andalucía Sunshine Tour 2025',
#        'CSI2* - 4th Week XXXI Andalucía Sunshine Tour 2025',
#        'CSIYH* - 5th Week XXXI Andalucía Sunshine Tour 2025',
#        'CSI4* - 5th Week XXXI Andalucía Sunshine Tour 2025',
#        'CSN2* Marzo - Real Club de Polo de Barcelona',
#        'Concurso Nacona de Saltos', 'SPRING MET III 2025 - YH*',
#        'CSIYH* - 6th Week XXXI Andalucía Sunshine Tour 2025',
#        'CSI4* - 6th Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET III 2025 - SILVER CSI1*',
#        'SPRING MET III 2025 - GOLD CSI2*',
#        'Andalucía Sunshine Tour CSIOYJCh 2025',
#        'SPRING MET III 2025 - BRONZE 1*', 'CSN3* Primavera RCP',
#        'CSIYH* - 7th Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET III - CSI1* SILVER',
#        'SPRING MET III 2025 - CSI3* GOLD',
#        'CSI4* - 7th Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET III 2025 - CSI1* BRONZE',
#        'CSN*** y CSNCJ EQUUS DURI MARZO', 'CSNCJ DE MARZO',
#        'CSN2* RSHECC', 'CSN1* CHAS MARZO 2025',
#        'SPRING MET III 2025 - CSI1* SILVER', 'CSN2* RIOS EQ - PRIMAVERA',
#        'CSN4* Ruta de Primavera',
#        'CSN2 - TROFEO OPEN SPORTS CLUB - MARZO',
#        'CSN5* Ruta de Primavera', 'SPRING MET IV 2025 - YH*',
#        'SPRING MET IV 2025 - 1* SILVER',
#        'SPRING MET IV 2025 - CSI2* GOLD',
#        'CSN*** Spring Showjumping - Heras Horses & Events',
#        'MOURATOURS VALENCIA', 'SPRING MET IV 2025 - CSI1* BRONZE',
#        'MOURA TOURS VALENCIA', 'CSN* C.H. DEL SUR - SEMANA SANTA',
#        'SPRING MET IV - YH*', 'SPRING MET IV - CSI1* SILVER',
#        'SPRING MET IV 2025 - CSI3* GOLD', 'MOURATOURS',
#        'MOURA TOURS VALENCIA - LIGA NACIONAL SALTO 2025',
#        'SPRING MET IV - CSI1* BRONZE', 'SPRING MET IV - CSI3* GOLD',
#        'CSN3* Copa Presidente'], dtype=object)

# %%
concursos_df_comb = df_final["Concurso"].unique()
concursos_df_comb
# Out:
# array(['SPRING MET I 2025 YH*', 'SPRING MET I 2025 - SILVER 1*',
#        'SPRING MET I 2025 - GOLD 2*',
#        'CSIYH* - 1st Week Andalucía Pre-Sunshine Tour 2025',
#        'CSI2* - 1st Week Andalucía Pre-Sunshine Tour 2025',
#        'SPRING MET I 2025 - BRONZE 1*',
#        'CSN2* Enero - Real Club de Polo de Barcelona',
#        'MOURA TOURS VALENCIA - SPRING TOUR', 'SPRING MET I 2025 - YH*',
#        'SPRING MET I 2025 - GOLD 3*',
#        'CSIYH* - 2nd Week Andalucía Pre-Sunshine Tour 2025',
#        'CSI3* - 2nd Week Andalucía Pre-Sunshine Tour 2025',
#        'CSN 3* LA HERRADURA', 'CSN3* Heras Winter Propenor Showjumping',
#        'CSN2* LAS CADENAS', 'CSN2* RACE',
#        'SPRING MET II 2025 - SILVER 1*',
#        'CSI4* - 2nd Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET II 2025 - GOLD 2*', 'SPRING MET II 2025 - BRONZE 1*',
#        'SPRING MET II 2025 - YH*',
#        'CSIYH* - 3rd Week XXXI Andalucía Sunshine Tour 2025',
#        'CSI4* - 3rd Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET II 2025 - GOLD 3*', 'CSN* C.H NUEVA ATALAYA',
#        'RUTA GRANADA HIPICA', '--MOURA TOURS VALENCIA - SPRING TOUR',
#        'CSI4* - 6th Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET III 2025 - SILVER CSI1*',
#        'SPRING MET III 2025 - GOLD CSI2*',
#        'Andalucía Sunshine Tour CSIOYJCh 2025',
#        'SPRING MET III 2025 - BRONZE 1*',
#        'CSIYH* - 7th Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET III 2025 - YH*', 'SPRING MET III - CSI1* SILVER',
#        'SPRING MET III 2025 - CSI3* GOLD',
#        'CSI4* - 7th Week XXXI Andalucía Sunshine Tour 2025',
#        'SPRING MET III 2025 - CSI1* BRONZE',
#        'CSN*** y CSNCJ EQUUS DURI MARZO', 'CSNCJ DE MARZO',
#        'CSN2* RSHECC', 'CSN1* CHAS MARZO 2025',
#        'SPRING MET III 2025 - CSI1* SILVER', 'CSN2* RIOS EQ - PRIMAVERA',
#        'CSN4* Ruta de Primavera',
#        'CSN2 - TROFEO OPEN SPORTS CLUB - MARZO',
#        'CSN5* Ruta de Primavera', 'SPRING MET IV - YH*',
#        'CSN* C.H. DEL SUR - SEMANA SANTA', 'SPRING MET IV - CSI1* SILVER',
#        'SPRING MET IV 2025 - CSI3* GOLD', 'MOURATOURS',
#        'MOURA TOURS VALENCIA - LIGA NACIONAL SALTO 2025',
#        'SPRING MET IV - CSI1* BRONZE', 'SPRING MET IV - CSI3* GOLD',
#        'CSN3* Copa Presidente'], dtype=object)

# %%
df_final[df_final["Concurso"] == "CSIYH* - 1st Week XXXI Andalucía Sunshine Tour 2025"]
# Out:
# Empty DataFrame
# Columns: [Concurso, Categoría, Provincia, Localidad, Disciplina, Federación, Resultados, País, Inicio, Final, Ambito, Estado, Posicion, Lic_jinete, Jinete, Pais_jinete, Lic_caballo, Caballo, Raza_caballo, Pais_caballo, Puntuacion, Premio, Dinero_premio, Prueba, Fecha_prueba, Ptos_obs_R1, Ptos_tiempo_R1, Tiempo_R1, Ptos_obs_R2, Ptos_tiempo_R2, Tiempo_R2, Ptos_obs_R3, Ptos_tiempo_R3, Tiempo_R3]
# Index: []

# %%
for concurso in concursos_df_original:
    if concurso not in concursos_df_comb:
        print(f"No está {concurso}")
    else:
        print(concurso)
# Out:
# No está CSN3* Invierno
# SPRING MET I 2025 YH*
# SPRING MET I 2025 - SILVER 1*
# SPRING MET I 2025 - GOLD 2*
# CSIYH* - 1st Week Andalucía Pre-Sunshine Tour 2025
# CSI2* - 1st Week Andalucía Pre-Sunshine Tour 2025
# SPRING MET I 2025 - BRONZE 1*
# CSN2* Enero - Real Club de Polo de Barcelona
# MOURA TOURS VALENCIA - SPRING TOUR
# SPRING MET I 2025 - YH*
# SPRING MET I 2025 - GOLD 3*
# CSIYH* - 2nd Week Andalucía Pre-Sunshine Tour 2025
# CSI3* - 2nd Week Andalucía Pre-Sunshine Tour 2025
# No está CSN2* RIOS EQ - WINTER CUP
# CSN 3* LA HERRADURA
# CSN3* Heras Winter Propenor Showjumping
# CSN2* LAS CADENAS
# CSN2* RACE
# No está CSIYH* - 1st Week XXXI Andalucía Sunshine Tour 2025
# No está CSI4* - 1st Week XXXI Andalucía Sunshine Tour 2025
# No está CSN3* Febrero - Real Club de Polo de Barcelona
# No está CSIYH* - 2nd Week XXXI Andalucía Sunshine Tour 2025
# SPRING MET II 2025 - YH*
# SPRING MET II 2025 - SILVER 1*
# CSI4* - 2nd Week XXXI Andalucía Sunshine Tour 2025
# SPRING MET II 2025 - GOLD 2*
# SPRING MET II 2025 - BRONZE 1*
# CSIYH* - 3rd Week XXXI Andalucía Sunshine Tour 2025
# CSI4* - 3rd Week XXXI Andalucía Sunshine Tour 2025
# SPRING MET II 2025 - GOLD 3*
# CSN* C.H NUEVA ATALAYA
# RUTA GRANADA HIPICA
# No está CSN3* F.H.M. - En Club Las Cadenas
# --MOURA TOURS VALENCIA - SPRING TOUR
# No está CSIYH* - 4th Week XXXI Andalucía Sunshine Tour 2025
# No está CSI2* - 4th Week XXXI Andalucía Sunshine Tour 2025
# No está CSIYH* - 5th Week XXXI Andalucía Sunshine Tour 2025
# No está CSI4* - 5th Week XXXI Andalucía Sunshine Tour 2025
# No está CSN2* Marzo - Real Club de Polo de Barcelona
# No está Concurso Nacona de Saltos
# SPRING MET III 2025 - YH*
# No está CSIYH* - 6th Week XXXI Andalucía Sunshine Tour 2025
# CSI4* - 6th Week XXXI Andalucía Sunshine Tour 2025
# SPRING MET III 2025 - SILVER CSI1*
# SPRING MET III 2025 - GOLD CSI2*
# Andalucía Sunshine Tour CSIOYJCh 2025
# SPRING MET III 2025 - BRONZE 1*
# No está CSN3* Primavera RCP
# CSIYH* - 7th Week XXXI Andalucía Sunshine Tour 2025
# SPRING MET III - CSI1* SILVER
# SPRING MET III 2025 - CSI3* GOLD
# CSI4* - 7th Week XXXI Andalucía Sunshine Tour 2025
# SPRING MET III 2025 - CSI1* BRONZE
# CSN*** y CSNCJ EQUUS DURI MARZO
# CSNCJ DE MARZO
# CSN2* RSHECC
# CSN1* CHAS MARZO 2025
# SPRING MET III 2025 - CSI1* SILVER
# CSN2* RIOS EQ - PRIMAVERA
# CSN4* Ruta de Primavera
# CSN2 - TROFEO OPEN SPORTS CLUB - MARZO
# CSN5* Ruta de Primavera
# No está SPRING MET IV 2025 - YH*
# No está SPRING MET IV 2025 - 1* SILVER
# No está SPRING MET IV 2025 - CSI2* GOLD
# No está CSN*** Spring Showjumping - Heras Horses & Events
# No está MOURATOURS VALENCIA
# No está SPRING MET IV 2025 - CSI1* BRONZE
# No está MOURA TOURS VALENCIA
# CSN* C.H. DEL SUR - SEMANA SANTA
# SPRING MET IV - YH*
# SPRING MET IV - CSI1* SILVER
# SPRING MET IV 2025 - CSI3* GOLD
# MOURATOURS
# MOURA TOURS VALENCIA - LIGA NACIONAL SALTO 2025
# SPRING MET IV - CSI1* BRONZE
# SPRING MET IV - CSI3* GOLD
# CSN3* Copa Presidente
