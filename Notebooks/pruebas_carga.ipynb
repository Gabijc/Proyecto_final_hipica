# %%
import pandas as pd
import json

# %%
with open('../data/data_salto/concursos/concursos_salto_nacional_2025.json', 'r', encoding='utf-8') as file:
    datos_concursos = json.load(file)

df_concursos = pd.DataFrame(datos_concursos)
df_concursos = df_concursos.rename(columns = {"Nombre": "Concurso", "Categoría": "Categoria_concurso"})
df_concursos["Concurso"] = df_concursos["Concurso"].str.strip()
df_concursos
# Out:
#                                               Concurso Categoria_concurso  \
# 0                                       CSN3* Invierno             CSN***
# 1                                SPRING MET I 2025 YH*            CSI YH*
# 2                        SPRING MET I 2025 - SILVER 1*               CSI*
# 3                          SPRING MET I 2025 - GOLD 2*              CSI**
# 4    CSIYH* - 1st Week Andalucía Pre-Sunshine Tour ...            CSI YH*
# ..                                                 ...                ...
# 119                                SPRING MET IV - YH*            CSI YH*
# 120                       SPRING MET IV - CSI1* SILVER               CSI*
# 121                         SPRING MET IV - CSI3* GOLD             CSI***
# 122                       SPRING MET IV - CSI1* BRONZE               CSI*
# 123                              CSN3* Copa Presidente             CSN***
#
#     Provincia                   Localidad           Disciplina  \
# 0     Sevilla            Real Club Pineda  Salto de Obstáculos
# 1    Valencia  Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 2    Valencia  Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 3    Valencia  Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 4       Cádiz          Dehesa Montenmedio  Salto de Obstáculos
# ..        ...                         ...                  ...
# 119  Valencia                        Ceon  Salto de Obstáculos
# 120  Valencia                        Ceon  Salto de Obstáculos
# 121  Valencia                        Ceon  Salto de Obstáculos
# 122  Valencia                        Ceon  Salto de Obstáculos
# 123   Sevilla            Real Club Pineda  Salto de Obstáculos
#
#                                  Federación Resultados   País      Inicio  \
# 0                Federación Hípica Andaluza        Ver  Epaña  10/01/2025
# 1    Federación Hípica Comunidad Valenciana        Ver  Epaña  14/01/2025
# 2    Federación Hípica Comunidad Valenciana        Ver  Epaña  16/01/2025
# 3    Federación Hípica Comunidad Valenciana        Ver  Epaña  16/01/2025
# 4                Federación Hípica Andaluza        Ver  Epaña  16/01/2025
# ..                                      ...        ...    ...         ...
# 119  Federación Hípica Comunidad Valenciana        Ver  Epaña  22/04/2025
# 120  Federación Hípica Comunidad Valenciana        Ver  Epaña  24/04/2025
# 121  Federación Hípica Comunidad Valenciana        Ver  Epaña  24/04/2025
# 122  Federación Hípica Comunidad Valenciana        Ver  Epaña  25/04/2025
# 123              Federación Hípica Andaluza        Ver  Epaña  25/04/2025
#
#           Final         Ambito
# 0    12/01/2025       Nacional
# 1    16/01/2025  Internacional
# 2    18/01/2025  Internacional
# 3    19/01/2025  Internacional
# 4    19/01/2025  Internacional
# ..          ...            ...
# 119  24/04/2025  Internacional
# 120  26/04/2025  Internacional
# 121  27/04/2025  Internacional
# 122  27/04/2025  Internacional
# 123  27/04/2025       Nacional
#
# [124 rows x 11 columns]

# %%
df_concursos.iloc[0,0]
# Out:
# 'CSN3* Invierno'

# %%
len(df_concursos["Concurso"].unique())
# Out:
# 78

# %%
pd.set_option('display.max_columns', None)

# %%
df_pruebas_resultados = pd.read_csv("../data/data_salto/resultados_combinados_2025.csv", index_col=0)
df_pruebas_resultados.head()
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_8160\1077302799.py:1: DtypeWarning: Columns (3,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pruebas_resultados = pd.read_csv("../data/data_salto/resultados_combinados_2025.csv", index_col=0)
#   Estado Posicion Lic_jinete                       Jinete Pais_jinete  \
# 0    FIN        1     284725  Pedro Miguel DA SILVA MANSO         ESP
# 1    FIN        2      77612        Ignacio ASTOLFI LÓPEZ         ESP
# 2    FIN        3     306183     Francisco PICAO CALDEIRA         ESP
# 3    FIN        4       1004          Jesús TORRES GARCÍA         ESP
# 4    FIN        5     367363              Nina FAGERSTROM         ESP
#
#   Lic_caballo              Caballo Raza_caballo Pais_caballo Puntuacion  \
# 0      169882  BRIDGETOWN JONES OS      (Indt.)          ESP    0/59,91
# 1      157373       QUINTO BLUE PS        OLDBG          ESP    0/63,23
# 2      145996         FLOR DU PASO        CRPOR          ESP    0/65,58
# 3      170075          DIABETTO PS        OLDBG          ESP    0/66,00
# 4      170155    HASENACHER CERVIN         ZANG          ESP    0/66,78
#
#    Premio  Dinero_premio                   Prueba Fecha_prueba  \
# 0    True          450.0  1,30 - A c.c. (238.2.1)   2025-01-10
# 1    True          300.0  1,30 - A c.c. (238.2.1)   2025-01-10
# 2    True          200.0  1,30 - A c.c. (238.2.1)   2025-01-10
# 3    True          150.0  1,30 - A c.c. (238.2.1)   2025-01-10
# 4    True          125.0  1,30 - A c.c. (238.2.1)   2025-01-10
#
#          Concurso Categoria  Ptos_obs_R1  Ptos_tiempo_R1  Tiempo_R1  \
# 0  CSN3* Invierno    CSN***          0.0             NaN      59.91
# 1  CSN3* Invierno    CSN***          0.0             NaN      63.23
# 2  CSN3* Invierno    CSN***          0.0             NaN      65.58
# 3  CSN3* Invierno    CSN***          0.0             NaN      66.00
# 4  CSN3* Invierno    CSN***          0.0             NaN      66.78
#
#    Ptos_obs_R2  Ptos_tiempo_R2  Tiempo_R2  Ptos_obs_R3  Ptos_tiempo_R3  \
# 0          NaN             NaN        NaN          NaN             NaN
# 1          NaN             NaN        NaN          NaN             NaN
# 2          NaN             NaN        NaN          NaN             NaN
# 3          NaN             NaN        NaN          NaN             NaN
# 4          NaN             NaN        NaN          NaN             NaN
#
#    Tiempo_R3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df_final = pd.merge(df_pruebas_resultados, df_concursos, on = "Concurso", how = "inner")
df_final['Fecha_prueba'] = pd.to_datetime(df_final['Fecha_prueba'])
df_final['Inicio'] = pd.to_datetime(df_final['Inicio'], dayfirst=True)
df_final['Final'] = pd.to_datetime(df_final['Final'], dayfirst=True)
df_final = df_final[(df_final['Fecha_prueba'] >= df_final['Inicio']) & (df_final['Fecha_prueba'] <= df_final['Final']) & (df_final["Categoria"] == df_final["Categoria_concurso"])]
df_final = df_final.drop(['Puntuacion', 'Resultados'], axis=1)
df_final["Jinete"] = df_final["Jinete"].str.lower()
df_final["Caballo"] = df_final["Caballo"].str.lower()
df_final["Lic_jinete"] = df_final["Lic_jinete"].astype(str)
df_final["Lic_caballo"] = df_final["Lic_caballo"].astype(str)
df_final["Raza_caballo"] = df_final["Raza_caballo"].apply(lambda x: None if x == '(Indt.)' else x)
# df_final["Lic_jinete"] = df_final["Lic_jinete"].apply(lambda x: None if x == '--' else x)
df_final["Lic_caballo"] = df_final["Lic_caballo"].apply(lambda x: None if x == '--' else x)
df_final.head()
# Out:
#   Estado Posicion Lic_jinete                       Jinete Pais_jinete  \
# 0    FIN        1     284725  pedro miguel da silva manso         ESP
# 1    FIN        2      77612        ignacio astolfi lópez         ESP
# 2    FIN        3     306183     francisco picao caldeira         ESP
# 3    FIN        4       1004          jesús torres garcía         ESP
# 4    FIN        5     367363              nina fagerstrom         ESP
#
#   Lic_caballo              Caballo Raza_caballo Pais_caballo  Premio  \
# 0      169882  bridgetown jones os         None          ESP    True
# 1      157373       quinto blue ps        OLDBG          ESP    True
# 2      145996         flor du paso        CRPOR          ESP    True
# 3      170075          diabetto ps        OLDBG          ESP    True
# 4      170155    hasenacher cervin         ZANG          ESP    True
#
#    Dinero_premio                   Prueba Fecha_prueba        Concurso  \
# 0          450.0  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 1          300.0  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 2          200.0  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 3          150.0  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
# 4          125.0  1,30 - A c.c. (238.2.1)   2025-01-10  CSN3* Invierno
#
#   Categoria  Ptos_obs_R1  Ptos_tiempo_R1  Tiempo_R1  Ptos_obs_R2  \
# 0    CSN***          0.0             NaN      59.91          NaN
# 1    CSN***          0.0             NaN      63.23          NaN
# 2    CSN***          0.0             NaN      65.58          NaN
# 3    CSN***          0.0             NaN      66.00          NaN
# 4    CSN***          0.0             NaN      66.78          NaN
#
#    Ptos_tiempo_R2  Tiempo_R2  Ptos_obs_R3  Ptos_tiempo_R3  Tiempo_R3  \
# 0             NaN        NaN          NaN             NaN        NaN
# 1             NaN        NaN          NaN             NaN        NaN
# 2             NaN        NaN          NaN             NaN        NaN
# 3             NaN        NaN          NaN             NaN        NaN
# 4             NaN        NaN          NaN             NaN        NaN
#
#   Categoria_concurso Provincia         Localidad           Disciplina  \
# 0             CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 1             CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 2             CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 3             CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
# 4             CSN***   Sevilla  Real Club Pineda  Salto de Obstáculos
#
#                    Federación   País     Inicio      Final    Ambito
# 0  Federación Hípica Andaluza  Epaña 2025-01-10 2025-01-12  Nacional
# 1  Federación Hípica Andaluza  Epaña 2025-01-10 2025-01-12  Nacional
# 2  Federación Hípica Andaluza  Epaña 2025-01-10 2025-01-12  Nacional
# 3  Federación Hípica Andaluza  Epaña 2025-01-10 2025-01-12  Nacional
# 4  Federación Hípica Andaluza  Epaña 2025-01-10 2025-01-12  Nacional

# %%
len(df_final["Concurso"].unique())
# Out:
# 75

# %%
df_final[df_final["Lic_jinete"] == "--"]
# Out:
#        Estado Posicion Lic_jinete    Jinete Pais_jinete Lic_caballo  \
# 2238      FIN        1         --  -- -- --         ESP     109AQ97
# 2281      FIN        2         --  -- -- --         ESP     109AQ97
# 2343      FIN        5         --  -- -- --         ESP     109AQ97
# 23957     FIN        2         --  -- -- --         ESP     109AQ96
# 23992     FIN        6         --  -- -- --         ESP     109AQ96
# 71451     FIN        1         --  -- -- --         ESP     109AQ97
# 71957     FIN        2         --  -- -- --         ESP     109AQ97
# 72443     FIN        7         --  -- -- --         ESP     109AQ97
# 94190     FIN       22         --  -- -- --         ESP     109AQ97
# 94724     FIN        1         --  -- -- --         ESP     109AQ97
# 95274     FIN       11         --  -- -- --         ESP     109AQ97
# 109892    FIN        9         --  -- -- --         ESP     109AQ97
# 110714    FIN        8         --  -- -- --         ESP     109AQ97
# 141326    FIN        1         --  -- -- --         ESP     109AQ96
# 141414    FIN        3         --  -- -- --         ESP     109AQ96
# 141516    FIN       15         --  -- -- --         ESP     109AQ96
# 147391    FIN        1         --  -- -- --         ESP     109AQ96
# 147813    FIN       17         --  -- -- --         ESP     109AQ96
# 148114    FIN        5         --  -- -- --         ESP     109AQ96
# 159924    ELI      ELI         --  -- -- --         ESP     109AQ96
# 160335    FIN        6         --  -- -- --         ESP     109AQ96
# 160802    FIN        8         --  -- -- --         ESP     109AQ96
# 166669    FIN       23         --  -- -- --         ESP     109AQ96
# 166947    FIN       15         --  -- -- --         ESP     109AQ96
#
#                    Caballo Raza_caballo Pais_caballo  Premio  Dinero_premio  \
# 2238    tarmitage de folch          CDE          ESP    True          55.94
# 2281    tarmitage de folch          CDE          ESP    True         100.00
# 2343    tarmitage de folch          CDE          ESP    True          35.00
# 23957       conan de folch          CDE          ESP    True         112.50
# 23992       conan de folch          CDE          ESP    True          27.50
# 71451   tarmitage de folch          CDE          ESP    True           8.83
# 71957   tarmitage de folch          CDE          ESP    True          60.00
# 72443   tarmitage de folch          CDE          ESP    True          12.00
# 94190   tarmitage de folch          CDE          ESP    True           0.00
# 94724   tarmitage de folch          CDE          ESP    True          75.00
# 95274   tarmitage de folch          CDE          ESP    True           7.50
# 109892  tarmitage de folch          CDE          ESP    True           9.00
# 110714  tarmitage de folch          CDE          ESP    True           9.00
# 141326      conan de folch          CDE          ESP    True          29.42
# 141414      conan de folch          CDE          ESP    True          75.00
# 141516      conan de folch          CDE          ESP    True           0.00
# 147391      conan de folch          CDE          ESP    True          12.00
# 147813      conan de folch          CDE          ESP    True           0.00
# 148114      conan de folch          CDE          ESP    True          21.00
# 159924      conan de folch          CDE          ESP    True           0.00
# 160335      conan de folch          CDE          ESP    True          16.50
# 160802      conan de folch          CDE          ESP    True           9.00
# 166669      conan de folch          CDE          ESP    True           0.00
# 166947      conan de folch          CDE          ESP    True           0.00
#
#                                             Prueba Fecha_prueba  \
# 2238    5 años - 1,05 - A sin cronómetro (238.1.1)   2025-01-16
# 2281              5 años - 1,05 - A c.c. (238.2.1)   2025-01-17
# 2343              5 años - 1,05 - A c.c. (238.2.1)   2025-01-18
# 23957             5 años - 1,05 - A c.c. (238.2.1)   2025-01-24
# 23957           0.0             NaN      42.34          NaN             NaN
# 23992           0.0             NaN      40.88          NaN             NaN
# 71451           NaN             0.0        NaN          NaN             NaN
# 71957           0.0             NaN      54.29          0.0             NaN
# 72443           0.0             NaN      44.64          0.0             NaN
# 94190           NaN             4.0        NaN          NaN             NaN
# 94724           0.0             NaN      38.90          0.0             NaN
# 95274           4.0             0.0      42.29          0.0             NaN
# 109892          0.0             NaN      43.61          4.0             0.0
# 110714          4.0             0.0      45.75          0.0             NaN
# 141326          NaN             0.0        NaN          NaN             NaN
# 141414          0.0             NaN      41.69          0.0             NaN
# 141516          0.0             NaN      35.54          8.0             0.0
# 147391          NaN             0.0        NaN          NaN             NaN
# 147813          0.0             NaN      47.65          NaN             NaN
# 148114          0.0             NaN      44.59          NaN             NaN
# 159924          NaN             NaN        NaN          NaN             NaN
# 160335          0.0             NaN      46.26          NaN             NaN
# 160802          0.0             NaN      43.97          NaN             NaN
# 166669          0.0             NaN      37.32          8.0             0.0
# 166947          4.0             0.0      79.43          NaN             NaN
#
#         Tiempo_R2  Ptos_obs_R3  Ptos_tiempo_R3  Tiempo_R3 Categoria_concurso  \
# 2238          NaN          NaN             NaN        NaN            CSI YH*
# 2281          NaN          NaN             NaN        NaN            CSI YH*
# 2343          NaN          NaN             NaN        NaN            CSI YH*
# 23957         NaN          NaN             NaN        NaN            CSI YH*
# 23992         NaN          NaN             NaN        NaN            CSI YH*
# 71451         NaN          NaN             NaN        NaN            CSI YH*
# 71957       24.94          NaN             NaN        NaN            CSI YH*
# 72443       36.52          NaN             NaN        NaN            CSI YH*
# 94190         NaN          NaN             NaN        NaN            CSI YH*
# 94724       33.27          NaN             NaN        NaN            CSI YH*
# 95274       34.36          NaN             NaN        NaN            CSI YH*
# 109892      38.43          NaN             NaN        NaN            CSI YH*
# 110714      32.86          NaN             NaN        NaN            CSI YH*
# 141326        NaN          NaN             NaN        NaN            CSI YH*
# 141414      31.09          NaN             NaN        NaN            CSI YH*
# 141516      41.56          NaN             NaN        NaN            CSI YH*
# 147391        NaN          NaN             NaN        NaN            CSI YH*
# 147813        NaN          NaN             NaN        NaN            CSI YH*
# 148114        NaN          NaN             NaN        NaN            CSI YH*
# 159924        NaN          NaN             NaN        NaN            CSI YH*
# 160335        NaN          NaN             NaN        NaN            CSI YH*
# 160802        NaN          NaN             NaN        NaN            CSI YH*
# 166669      45.86          NaN             NaN        NaN            CSI YH*
# 166947        NaN          NaN             NaN        NaN            CSI YH*
#
#        Provincia           Localidad           Disciplina  \
# 2238       Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 2281       Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 2343       Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 23957      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 23992      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 71451      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 71957      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 72443      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 94190      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 94724      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 95274      Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 109892     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 110714     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 141326     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 141414     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 141516     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 147391     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 147813     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 148114     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 159924     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 160335     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 160802     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 166669     Cádiz  Dehesa Montenmedio  Salto de Obstáculos
# 1777       108KT26  que cera van 't ruytershof          NaN          BEL
# 177306     107BA95                    emmie cc          NaN          SWE
# 178956     106UL53                  nimmer fbh         HANN          ESP
# 2087       108IA67              fundao semilly          NaN          SUI
# 183591     108OE21                   nevada te          NaN          IRL
# 86726      109AY44            javotte de bedon          NaN          FRA
# 162130     107NH63         gentleman riverland          NaN          FRA
#
#         Premio  Dinero_premio                                    Prueba  \
# 182583    True            0.0   1,45 (G) - A.c.c. y desempate (238.2.2)
# 157932    True            0.0                      1,10 - Acc (238.2.1)
# 144316    True            0.0               1,45 (G) - A c.c. (238.2.1)
# 1777      True            0.0          1,40 (G) - Dos Fases (274.1.5.3)
# 177306    True            0.0               1,40 (G) - A c.c. (238.2.1)
# 178956    True            0.0  1,40 (GP) - A.c.c. y desempate (238.2.2)
# 2087      True            0.0   1,45 (G) - A.c.c. y desempate (238.2.2)
# 183591    True           42.0                   1,20 - A c.c. (238.2.1)
# 86726     True            0.0         1,20 - Dos Fases Especial (274.2)
# 162130    True            0.0               1,35 (G) - A c.c. (238.2.1)
#
#        Fecha_prueba                                           Concurso  \
# 182583   2025-04-12                    SPRING MET IV 2025 - CSI2* GOLD
# 157932   2025-03-07       CSN2* Marzo - Real Club de Polo de Barcelona
# 144316   2025-02-27                       SPRING MET II 2025 - GOLD 3*
# 1777     2025-01-16                        SPRING MET I 2025 - GOLD 2*
# 177306   2025-03-29                   SPRING MET III 2025 - CSI3* GOLD
# 178956   2025-03-30                 SPRING MET III 2025 - CSI1* BRONZE
# 2087     2025-01-18                        SPRING MET I 2025 - GOLD 2*
# 183591   2025-04-12                  SPRING MET IV 2025 - CSI1* BRONZE
# 86726    2025-02-15                 MOURA TOURS VALENCIA - SPRING TOUR
# 162130   2025-03-14  CSI4* - 6th Week XXXI Andalucía Sunshine Tour ...
#
#        Categoria  Ptos_obs_R1  Ptos_tiempo_R1  Tiempo_R1  Ptos_obs_R2  \
# 182583     CSI**          4.0             0.0      72.42          NaN
# 157932     CSN**          4.0             0.0      83.71          NaN
# 144316    CSI***          8.0             0.0      73.03          NaN
# 1777       CSI**          0.0             NaN      49.51          4.0
# 177306    CSI***          8.0             4.0      87.23          NaN
# 178956      CSI*          4.0             0.0      74.17          NaN
# 2087       CSI**          NaN             NaN        NaN          NaN
# 183591      CSI*          0.0             NaN      61.15          NaN
# 86726       CSI*          0.0             NaN      42.62          4.0
# 162130   CSI****          0.0             NaN      72.79          NaN
#
#         Ptos_tiempo_R2  Tiempo_R2  Ptos_obs_R3  Ptos_tiempo_R3  Tiempo_R3  \
# 182583             NaN        NaN          NaN             NaN        NaN
# 157932             NaN        NaN          NaN             NaN        NaN
# 144316             NaN        NaN          NaN             NaN        NaN
# 1777               2.0      35.04          NaN             NaN        NaN
# 177306             NaN        NaN          NaN             NaN        NaN
# 178956             NaN        NaN          NaN             NaN        NaN
# 2087               NaN        NaN          NaN             NaN        NaN
# 183591             NaN        NaN          NaN             NaN        NaN
# 86726              0.0      40.67          NaN             NaN        NaN
# 162130             NaN        NaN          NaN             NaN        NaN
#
#        Categoria_concurso  Provincia                       Localidad  \
# 182583              CSI**   Valencia                            Ceon
# 157932              CSN**  Barcelona  Real Club De Polo De Barcelona
# 144316             CSI***   Valencia      Centro Ecuestre Oliva Nova
# 1777                CSI**   Valencia      Centro Ecuestre Oliva Nova
# 177306             CSI***   Valencia      Centro Ecuestre Oliva Nova
# 178956               CSI*   Valencia      Centro Ecuestre Oliva Nova
# 2087                CSI**   Valencia      Centro Ecuestre Oliva Nova
# 183591               CSI*   Valencia      Centro Ecuestre Oliva Nova
# 86726                CSI*   Valencia                     Moura Tours
# 162130            CSI****      Cádiz              Dehesa Montenmedio
#
#                  Disciplina                              Federación   País  \
# 182583  Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 157932  Salto de Obstáculos             Federació Catalana d'Hípica  Epaña
# 144316  Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 1777    Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 177306  Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 178956  Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 2087    Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 183591  Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 86726   Salto de Obstáculos  Federación Hípica Comunidad Valenciana  Epaña
# 162130  Salto de Obstáculos              Federación Hípica Andaluza  Epaña
#
#            Inicio      Final         Ambito
# 182583 2025-04-10 2025-04-13  Internacional
# 157932 2025-03-07 2025-03-09       Nacional
# 144316 2025-02-27 2025-03-02  Internacional
# 1777   2025-01-16 2025-01-19  Internacional
# 177306 2025-03-27 2025-03-30  Internacional
# 178956 2025-03-28 2025-03-30  Internacional
# 2087   2025-01-16 2025-01-19  Internacional
# 183591 2025-04-11 2025-04-13  Internacional
# 86726  2025-02-10 2025-02-16  Internacional
# 162130 2025-03-13 2025-03-16  Internacional

# %%
df = df_final[df_final["Lic_caballo"].duplicated()]
df_final[df["Lic_caballo"] == ]
# Out:
#       Estado Posicion Lic_jinete           Jinete Pais_jinete Lic_caballo  \
# 699      FIN        7   10136751  rose de balanda         FRA     108VY29
# 20454    FIN        1   10136751  rose de balanda         FRA     108VY29
# 20736    FIN       18   10136751  rose de balanda         FRA     108VY29
# 48054    FIN       32   10136751  rose de balanda         FRA     108VY29
# 48212    FIN       23   10136751  rose de balanda         FRA     108VY29
#
#                Caballo Raza_caballo Pais_caballo  Premio  Dinero_premio  \
# 699    imagine de gaia          NaN          FRA    True          48.00
# 20454  imagine de gaia          NaN          FRA    True          27.37
# 20736  imagine de gaia          NaN          FRA    True           0.00
# 48054  imagine de gaia          NaN          FRA    True           0.00
# 48212  imagine de gaia          NaN          FRA    True           0.00
#
#                                              Prueba Fecha_prueba  \
# 699      7 años - 1,35 - Dos Fases Especial (274.2)   2025-01-16
# 20454    7 años - 1,35 - A sin cronómetro (238.1.1)   2025-01-21
# 20736  7 años - 1,35 - A.c.c. y desempate (238.2.2)   2025-01-22
# 48054    7 años - 1,35 - A sin cronómetro (238.1.1)   2025-01-28
# 48212  7 años - 1,40 - A.c.c. y desempate (238.2.2)   2025-01-29
#
#                       Concurso Categoria  Ptos_obs_R1  Ptos_tiempo_R1  \
# 699      SPRING MET I 2025 YH*   CSI YH*          0.0             NaN
# 20454  SPRING MET I 2025 - YH*   CSI YH*          0.0             NaN
# 20736  SPRING MET I 2025 - YH*   CSI YH*          0.0             NaN
# 48054  SPRING MET I 2025 - YH*   CSI YH*          4.0             1.0
# 48212  SPRING MET I 2025 - YH*   CSI YH*          4.0             0.0
#
#        Tiempo_R1  Ptos_obs_R2  Ptos_tiempo_R2  Tiempo_R2  Ptos_obs_R3  \
# 699        35.43          0.0             NaN      42.04          NaN
# 20454      78.16          NaN             NaN        NaN          NaN
# 20736      72.26          0.0             NaN      41.07          NaN
# 48054      86.42          NaN             NaN        NaN          NaN
# 48212      77.25          NaN             NaN        NaN          NaN
#
#        Ptos_tiempo_R3  Tiempo_R3 Categoria_concurso Provincia  \
# 699               NaN        NaN            CSI YH*  Valencia
# 20454             NaN        NaN            CSI YH*  Valencia
# 20736             NaN        NaN            CSI YH*  Valencia
# 48054             NaN        NaN            CSI YH*  Valencia
# 48212             NaN        NaN            CSI YH*  Valencia
#
#                         Localidad           Disciplina  \
# 699    Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 20454  Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 20736  Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 48054  Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 48212  Centro Ecuestre Oliva Nova  Salto de Obstáculos
#
#                                    Federación   País     Inicio      Final  \
# 699    Federación Hípica Comunidad Valenciana  Epaña 2025-01-14 2025-01-16
# 20454  Federación Hípica Comunidad Valenciana  Epaña 2025-01-21 2025-01-23
# 20736  Federación Hípica Comunidad Valenciana  Epaña 2025-01-21 2025-01-23
# 48054  Federación Hípica Comunidad Valenciana  Epaña 2025-01-28 2025-01-30
# 48212  Federación Hípica Comunidad Valenciana  Epaña 2025-01-28 2025-01-30
#
#               Ambito
# 699    Internacional
# 20454  Internacional
# 20736  Internacional
# 48054  Internacional
# 48212  Internacional

# %%
df = df_final[df_final["Lic_caballo"].duplicated()]
print(df["Lic_caballo"].unique())
# Out:
# ['108RB55' '108ZX27' '109BO22' ... '109899' '164581' '169078']

# %%
coso = list(df_final["Lic_jinete"].unique())

if None in coso:
    print("nulo")
else:
    print("todo ok")
# Out:
# nulo

# %%
df_final["Lic_caballo"].duplicated().sum()
# Out:
# np.int64(55135)

# %%
df_final.to_pickle("../data/data_salto/informacion_concursos_final.pkl")

# %%
df = pd.read_pickle("../data/data_salto/informacion_concursos_final.pkl")
df["Caballo"].duplicated().sum()
# Out:
# np.int64(55904)

# %%
print(df["Lic_caballo"].unique())
# Out:
# ['169882' '157373' '145996' ... 159094 155590 163007]
