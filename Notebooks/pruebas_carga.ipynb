# %%
import pandas as pd
import json

# %%
with open('../data/data_salto/concursos/concursos_salto_nacional_2025.json', 'r', encoding='utf-8') as file:
    datos_concursos = json.load(file)

df_concursos = pd.DataFrame(datos_concursos)
df_concursos = df_concursos.rename(columns = {"Nombre": "Concurso"})
df_concursos
# Out:
#                                               Concurso Categoría Provincia  \
# 0                                       CSN3* Invierno    CSN***   Sevilla
# 1                                SPRING MET I 2025 YH*   CSI YH*  Valencia
# 2                        SPRING MET I 2025 - SILVER 1*      CSI*  Valencia
# 3                          SPRING MET I 2025 - GOLD 2*     CSI**  Valencia
# 4    CSIYH* - 1st Week Andalucía Pre-Sunshine Tour ...   CSI YH*     Cádiz
# ..                                                 ...       ...       ...
# 119                                SPRING MET IV - YH*   CSI YH*  Valencia
# 120                       SPRING MET IV - CSI1* SILVER      CSI*  Valencia
# 121                         SPRING MET IV - CSI3* GOLD    CSI***  Valencia
# 122                       SPRING MET IV - CSI1* BRONZE      CSI*  Valencia
# 123                              CSN3* Copa Presidente    CSN***   Sevilla
#
#                       Localidad           Disciplina  \
# 0              Real Club Pineda  Salto de Obstáculos
# 1    Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 2    Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 3    Centro Ecuestre Oliva Nova  Salto de Obstáculos
# 4            Dehesa Montenmedio  Salto de Obstáculos
# ..                          ...                  ...
# 119                        Ceon  Salto de Obstáculos
# 120                        Ceon  Salto de Obstáculos
# 121                        Ceon  Salto de Obstáculos
# 122                        Ceon  Salto de Obstáculos
# 123            Real Club Pineda  Salto de Obstáculos
#
#                                  Federación Resultados   País      Inicio  \
# 0                Federación Hípica Andaluza        Ver  Epaña  10/01/2025
# 1    Federación Hípica Comunidad Valenciana        Ver  Epaña  14/01/2025
# 2    Federación Hípica Comunidad Valenciana        Ver  Epaña  16/01/2025
# 3    Federación Hípica Comunidad Valenciana        Ver  Epaña  16/01/2025
# 4                Federación Hípica Andaluza        Ver  Epaña  16/01/2025
# ..                                      ...        ...    ...         ...
# 119  Federación Hípica Comunidad Valenciana        Ver  Epaña  22/04/2025
# 120  Federación Hípica Comunidad Valenciana        Ver  Epaña  24/04/2025
# 121  Federación Hípica Comunidad Valenciana        Ver  Epaña  24/04/2025
# 122  Federación Hípica Comunidad Valenciana        Ver  Epaña  25/04/2025
# 123              Federación Hípica Andaluza        Ver  Epaña  25/04/2025
#
#           Final         Ambito
# 0    12/01/2025       Nacional
# 1    16/01/2025  Internacional
# 2    18/01/2025  Internacional
# 3    19/01/2025  Internacional
# 4    19/01/2025  Internacional
# ..          ...            ...
# 119  24/04/2025  Internacional
# 120  26/04/2025  Internacional
# 121  27/04/2025  Internacional
# 122  27/04/2025  Internacional
# 123  27/04/2025       Nacional
#
# [124 rows x 11 columns]

# %%
df_pruebas_resultados = pd.read_pickle("../data/data_salto/resultados_combinados_2025.pkl")
df_pruebas_resultados
# Out:
#       Estado Posicion Lic_jinete                          Jinete Pais_jinete  \
# 0        FIN        1     284725     Pedro Miguel DA SILVA MANSO         ESP
# 1        FIN        2      77612           Ignacio ASTOLFI LÓPEZ         ESP
# 2        FIN        3     306183        Francisco PICAO CALDEIRA         ESP
# 3        FIN        4       1004             Jesús TORRES GARCÍA         ESP
# 4        FIN        5     367363                 Nina FAGERSTROM         ESP
# ...      ...      ...        ...                             ...         ...
# 66033    FIN       23      77612           Ignacio ASTOLFI LÓPEZ         ESP
# 66034    FIN       24      37013           Alejandro ALONSO BUZO         ESP
# 66035    RET      RET      16879  Patricio DE VALDENEBRO DEL REY         ESP
# 66036    NOP      NOP     196126      Francisco ROMÁN CANTILLANA         ESP
# 66037    NOP      NOP     196126      Francisco ROMÁN CANTILLANA         ESP
#
#       Lic_caballo                  Caballo Raza_caballo Pais_caballo  \
# 0          169882      BRIDGETOWN JONES OS      (Indt.)          ESP
# 1          157373           QUINTO BLUE PS        OLDBG          ESP
# 2          145996             FLOR DU PASO        CRPOR          ESP
# 3          170075              DIABETTO PS        OLDBG          ESP
# 4          170155        HASENACHER CERVIN         ZANG          ESP
# ...           ...                      ...          ...          ...
# 66033      158640        GRUPO PROM JIVARO          BWP          ESP
# 66034      159094          HOUSTON DU GAST      (Indt.)          ESP
# 66035      133477  KLIMAX VAN HET LINDEHOF          BWP          ESP
# 66036      155590         ULOUBET DE VANAU           SF          ESP
# 66037      163007         GAROU DE BLONDEL           SF          ESP
#
#                                        Puntuacion  ...        Concurso  \
# 0                                         0/59,91  ...  CSN3* Invierno
# 1                                         0/63,23  ...  CSN3* Invierno
# 2                                         0/65,58  ...  CSN3* Invierno
# 3                                         0/66,00  ...  CSN3* Invierno
# 4                                         0/66,78  ...  CSN3* Invierno
# ...                                           ...  ...             ...
# 66033                 0\n21(12 Obs - 9 Tpo)/48,62  ...  CSN3* Invierno
# 66034  25(8 Obs - 17 Tpo)\n2(0 Obs - 2 Tpo)/41,45  ...  CSN3* Invierno
# 66035                                         RET  ...  CSN3* Invierno
# 66036                                         NOP  ...  CSN3* Invierno
# 66037                                         NOP  ...  CSN3* Invierno
#
#       Ptos_obs_R1 Ptos_tiempo_R1 Tiempo_R1 Ptos_obs_R2 Ptos_tiempo_R2  \
# 0             0.0            NaN     59.91        None           None
# 1             0.0            NaN     63.23        None           None
# 2             0.0            NaN     65.58        None           None
# 3             0.0            NaN      66.0        None           None
# 4             0.0            NaN     66.78        None           None
# ...           ...            ...       ...         ...            ...
# 66033         0.0            NaN      None        12.0            9.0
# 66034         8.0           17.0      None         0.0            2.0
# 66035         NaN            NaN      None         NaN            NaN
# 66036         NaN            NaN      None         NaN            NaN
# 66037         NaN            NaN      None         NaN            NaN
#
#       Tiempo_R2 Ptos_obs_R3 Ptos_tiempo_R3 Tiempo_R3
# 0          None        None           None      None
# 1          None        None           None      None
# 2          None        None           None      None
# 3          None        None           None      None
# 4          None        None           None      None
# ...         ...         ...            ...       ...
# 66033     48.62        None           None      None
# 66034     41.45        None           None      None
# 66035       NaN        None           None      None
# 66036       NaN        None           None      None
# 66037       NaN        None           None      None
#
# [66038 rows x 24 columns]
